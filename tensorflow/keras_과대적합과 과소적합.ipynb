# %%
import tensorflow as tf
from tensorflow import keras

import numpy as np
import matplotlib.pyplot as plt

print(tf.__version__)
# Out:
# 2.4.1

# %% [markdown]
# 앞서 영화 리뷰 분류와 주택 가격 예측의 두 예제에서 일정 에포크 동안 훈련하면 검증 세트에서 모델 성능이 최고점에 도달한 다음 감소하기 시작한 것을 보았습니다.
#
# 다른 말로 하면, 모델이 훈련 세트에 과대적합(overfitting)된 것입니다. 과대적합을 다루는 방법은 꼭 배워야 합니다. 훈련 세트에서 높은 성능을 얻을 수 있지만 진짜 원하는 것은 테스트 세트(또는 이전에 본 적 없는 데이터)에 잘 일반화되는 모델입니다.
#
# 과대적합의 반대는 과소적합(underfitting)입니다. 과소적합은 테스트 세트의 성능이 향상될 여지가 아직 있을 때 일어납니다. 발생하는 원인은 여러가지입니다. 모델이 너무 단순하거나, 규제가 너무 많거나, 그냥 단순히 충분히 오래 훈련하지 않는 경우입니다. 즉 네트워크가 훈련 세트에서 적절한 패턴을 학습하지 못했다는 뜻입니다.
#
# 모델을 너무 오래 훈련하면 과대적합되기 시작하고 테스트 세트에서 일반화되지 못하는 패턴을 훈련 세트에서 학습합니다. 과대적합과 과소적합 사이에서 균형을 잡아야 합니다. 이를 위해 적절한 에포크 횟수동안 모델을 훈련하는 방법을 배워보겠습니다.
#
# 과대적합을 막는 가장 좋은 방법은 더 많은 훈련 데이터를 사용하는 것입니다. 많은 데이터에서 훈련한 모델은 자연적으로 일반화 성능이 더 좋습니다. 데이터를 더 준비할 수 없을 때 그다음으로 가장 좋은 방법은 규제(regularization)와 같은 기법을 사용하는 것입니다. 모델이 저장할 수 있는 정보의 양과 종류에 제약을 부과하는 방법입니다. 네트워크가 소수의 패턴만 기억할 수 있다면 최적화 과정 동안 일반화 가능성이 높은 가장 중요한 패턴에 촛점을 맞출 것입니다.

# %%
NUM_WORDS = 1000

(train_data, train_labels), (test_data, test_labels) = keras.datasets.imdb.load_data(num_words=NUM_WORDS)

def multi_hot_sequences(sequences, dimension):
    # 0으로 채워진 (len(sequences), dimension) 크기의 행렬을 만듭니다
    results = np.zeros((len(sequences), dimension))
    for i, word_indices in enumerate(sequences):
        results[i, word_indices] = 1.0  # results[i]의 특정 인덱스만 1로 설정합니다
    return results


train_data = multi_hot_sequences(train_data, dimension=NUM_WORDS)
test_data = multi_hot_sequences(test_data, dimension=NUM_WORDS)
# Out:
# <string>:6: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# C:\Users\chaeh\anaconda3\lib\site-packages\tensorflow\python\keras\datasets\imdb.py:159: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   x_train, y_train = np.array(xs[:idx]), np.array(labels[:idx])
# C:\Users\chaeh\anaconda3\lib\site-packages\tensorflow\python\keras\datasets\imdb.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   x_test, y_test = np.array(xs[idx:]), np.array(labels[idx:])

# %%
plt.plot(train_data[0])

# %% [markdown]
# 과대적합을 막는 가장 간단한 방법은 모델의 규모를 축소하는 것입니다. 즉, 모델에 있는 학습 가능한 파라미터의 수를 줄입니다(모델 파라미터는 층(layer)의 개수와 층의 유닛(unit) 개수에 의해 결정됩니다).
#
# 항상 기억해야 할 점은 딥러닝 모델이 훈련 세트에는 학습이 잘 되는 경향이 있지만 진짜 해결할 문제는 학습이 아니라 일반화라는 것입니다.
#
# 안타깝지만 어떤 모델의 (층의 개수나 뉴런 개수에 해당하는) 적절한 크기나 구조를 결정하는 마법같은 공식은 없습니다. 여러 가지 다른 구조를 사용해 실험을 해봐야만 합니다.
#
# 알맞은 모델의 크기를 찾으려면 비교적 적은 수의 층과 파라미터로 시작해서 검증 손실이 감소할 때까지 새로운 층을 추가하거나 층의 크기를 늘리는 것이 좋습니다. 영화 리뷰 분류 네트워크를 사용해 이를 실험해 보죠.
#
# Dense 층만 사용하는 간단한 기준 모델을 만들고 작은 규모의 버전와 큰 버전의 모델을 만들어 비교하겠습니다.

# %% [markdown]
# ## 기준모델만들기

# %%
baseline_model = keras.Sequential([
    # `.summary` 메서드 때문에 `input_shape`가 필요합니다
    keras.layers.Dense(16, activation='relu', input_shape=(NUM_WORDS,)),
    keras.layers.Dense(16, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])

baseline_model.compile(optimizer='adam',
                       loss='binary_crossentropy',
                       metrics=['accuracy', 'binary_crossentropy'])

baseline_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 16)                16016
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                272
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 16,305
# Trainable params: 16,305
# Non-trainable params: 0
# _________________________________________________________________

# %%
baseline_history = baseline_model.fit(train_data,
                                      train_labels,
                                      epochs=20,
                                      batch_size=512,
                                      validation_data=(test_data, test_labels),
                                      verbose=2)
# Out:
# Epoch 1/20
# 49/49 - 2s - loss: 0.5552 - accuracy: 0.7158 - binary_crossentropy: 0.5552 - val_loss: 0.4074 - val_accuracy: 0.8280 - val_binary_crossentropy: 0.4074
# Epoch 2/20
# 49/49 - 0s - loss: 0.3551 - accuracy: 0.8490 - binary_crossentropy: 0.3551 - val_loss: 0.3402 - val_accuracy: 0.8556 - val_binary_crossentropy: 0.3402
# Epoch 3/20
# 49/49 - 0s - loss: 0.3173 - accuracy: 0.8681 - binary_crossentropy: 0.3173 - val_loss: 0.3327 - val_accuracy: 0.8585 - val_binary_crossentropy: 0.3327
# Epoch 4/20
# 49/49 - 0s - loss: 0.3049 - accuracy: 0.8740 - binary_crossentropy: 0.3049 - val_loss: 0.3287 - val_accuracy: 0.8588 - val_binary_crossentropy: 0.3287
# Epoch 5/20
# 49/49 - 0s - loss: 0.2981 - accuracy: 0.8781 - binary_crossentropy: 0.2981 - val_loss: 0.3295 - val_accuracy: 0.8591 - val_binary_crossentropy: 0.3295
# Epoch 6/20
# 49/49 - 0s - loss: 0.2942 - accuracy: 0.8799 - binary_crossentropy: 0.2942 - val_loss: 0.3291 - val_accuracy: 0.8596 - val_binary_crossentropy: 0.3291
# Epoch 7/20
# 49/49 - 0s - loss: 0.2889 - accuracy: 0.8816 - binary_crossentropy: 0.2889 - val_loss: 0.3312 - val_accuracy: 0.8583 - val_binary_crossentropy: 0.3312
# Epoch 8/20
# 49/49 - 0s - loss: 0.2833 - accuracy: 0.8832 - binary_crossentropy: 0.2833 - val_loss: 0.3321 - val_accuracy: 0.8592 - val_binary_crossentropy: 0.3321
# Epoch 9/20
# 49/49 - 0s - loss: 0.2767 - accuracy: 0.8862 - binary_crossentropy: 0.2767 - val_loss: 0.3326 - val_accuracy: 0.8594 - val_binary_crossentropy: 0.3326
# Epoch 10/20
# 49/49 - 0s - loss: 0.2716 - accuracy: 0.8878 - binary_crossentropy: 0.2716 - val_loss: 0.3378 - val_accuracy: 0.8575 - val_binary_crossentropy: 0.3378
# Epoch 11/20
# 49/49 - 0s - loss: 0.2666 - accuracy: 0.8908 - binary_crossentropy: 0.2666 - val_loss: 0.3423 - val_accuracy: 0.8554 - val_binary_crossentropy: 0.3423
# Epoch 12/20
# 49/49 - 0s - loss: 0.2601 - accuracy: 0.8936 - binary_crossentropy: 0.2601 - val_loss: 0.3382 - val_accuracy: 0.8572 - val_binary_crossentropy: 0.3382
# Epoch 13/20
# 49/49 - 0s - loss: 0.2541 - accuracy: 0.8964 - binary_crossentropy: 0.2541 - val_loss: 0.3395 - val_accuracy: 0.8569 - val_binary_crossentropy: 0.3395
# Epoch 14/20
# 49/49 - 0s - loss: 0.2472 - accuracy: 0.8982 - binary_crossentropy: 0.2472 - val_loss: 0.3465 - val_accuracy: 0.8530 - val_binary_crossentropy: 0.3465
# Epoch 15/20
# 49/49 - 0s - loss: 0.2421 - accuracy: 0.9014 - binary_crossentropy: 0.2421 - val_loss: 0.3467 - val_accuracy: 0.8557 - val_binary_crossentropy: 0.3467
# Epoch 16/20
# 49/49 - 0s - loss: 0.2360 - accuracy: 0.9038 - binary_crossentropy: 0.2360 - val_loss: 0.3541 - val_accuracy: 0.8532 - val_binary_crossentropy: 0.3541
# Epoch 17/20
# 49/49 - 0s - loss: 0.2297 - accuracy: 0.9077 - binary_crossentropy: 0.2297 - val_loss: 0.3571 - val_accuracy: 0.8527 - val_binary_crossentropy: 0.3571
# Epoch 18/20
# 49/49 - 0s - loss: 0.2248 - accuracy: 0.9098 - binary_crossentropy: 0.2248 - val_loss: 0.3610 - val_accuracy: 0.8510 - val_binary_crossentropy: 0.3610
# Epoch 19/20
# 49/49 - 0s - loss: 0.2196 - accuracy: 0.9105 - binary_crossentropy: 0.2196 - val_loss: 0.3649 - val_accuracy: 0.8522 - val_binary_crossentropy: 0.3649
# Epoch 20/20
# 49/49 - 0s - loss: 0.2135 - accuracy: 0.9152 - binary_crossentropy: 0.2135 - val_loss: 0.3648 - val_accuracy: 0.8505 - val_binary_crossentropy: 0.3648

# %% [markdown]
# ## 작은모델만들기

# %%
smaller_model = keras.Sequential([
    keras.layers.Dense(4, activation='relu', input_shape=(NUM_WORDS,)),
    keras.layers.Dense(4, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])

smaller_model.compile(optimizer='adam',
                      loss='binary_crossentropy',
                      metrics=['accuracy', 'binary_crossentropy'])

smaller_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 4)                 4004
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 20
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 5
# =================================================================
# Total params: 4,029
# Trainable params: 4,029
# Non-trainable params: 0
# _________________________________________________________________

# %%
smaller_history = smaller_model.fit(train_data,
                                    train_labels,
                                    epochs=20,
                                    batch_size=512,
                                    validation_data=(test_data, test_labels),
                                    verbose=2)
# Out:
# Epoch 1/20
# 49/49 - 1s - loss: 0.6523 - accuracy: 0.6506 - binary_crossentropy: 0.6523 - val_loss: 0.5947 - val_accuracy: 0.7384 - val_binary_crossentropy: 0.5947
# Epoch 2/20
# 49/49 - 0s - loss: 0.5278 - accuracy: 0.8045 - binary_crossentropy: 0.5278 - val_loss: 0.4751 - val_accuracy: 0.8226 - val_binary_crossentropy: 0.4751
# Epoch 3/20
# 49/49 - 0s - loss: 0.4262 - accuracy: 0.8452 - binary_crossentropy: 0.4262 - val_loss: 0.4031 - val_accuracy: 0.8432 - val_binary_crossentropy: 0.4031
# Epoch 4/20
# 49/49 - 0s - loss: 0.3707 - accuracy: 0.8567 - binary_crossentropy: 0.3707 - val_loss: 0.3644 - val_accuracy: 0.8515 - val_binary_crossentropy: 0.3644
# Epoch 5/20
# 49/49 - 0s - loss: 0.3414 - accuracy: 0.8638 - binary_crossentropy: 0.3414 - val_loss: 0.3465 - val_accuracy: 0.8566 - val_binary_crossentropy: 0.3465
# Epoch 6/20
# 49/49 - 0s - loss: 0.3252 - accuracy: 0.8688 - binary_crossentropy: 0.3252 - val_loss: 0.3372 - val_accuracy: 0.8585 - val_binary_crossentropy: 0.3372
# Epoch 7/20
# 49/49 - 0s - loss: 0.3157 - accuracy: 0.8707 - binary_crossentropy: 0.3157 - val_loss: 0.3334 - val_accuracy: 0.8593 - val_binary_crossentropy: 0.3334
# Epoch 8/20
# 49/49 - 0s - loss: 0.3094 - accuracy: 0.8748 - binary_crossentropy: 0.3094 - val_loss: 0.3300 - val_accuracy: 0.8602 - val_binary_crossentropy: 0.3300
# Epoch 9/20
# 49/49 - 0s - loss: 0.3057 - accuracy: 0.8753 - binary_crossentropy: 0.3057 - val_loss: 0.3293 - val_accuracy: 0.8594 - val_binary_crossentropy: 0.3293
# Epoch 10/20
# 49/49 - 0s - loss: 0.3026 - accuracy: 0.8765 - binary_crossentropy: 0.3026 - val_loss: 0.3283 - val_accuracy: 0.8596 - val_binary_crossentropy: 0.3283
# Epoch 11/20
# 49/49 - 0s - loss: 0.3008 - accuracy: 0.8772 - binary_crossentropy: 0.3008 - val_loss: 0.3288 - val_accuracy: 0.8596 - val_binary_crossentropy: 0.3288
# Epoch 12/20
# 49/49 - 0s - loss: 0.2993 - accuracy: 0.8789 - binary_crossentropy: 0.2993 - val_loss: 0.3288 - val_accuracy: 0.8600 - val_binary_crossentropy: 0.3288
# Epoch 13/20
# 49/49 - 0s - loss: 0.2977 - accuracy: 0.8779 - binary_crossentropy: 0.2977 - val_loss: 0.3296 - val_accuracy: 0.8599 - val_binary_crossentropy: 0.3296
# Epoch 14/20
# 49/49 - 0s - loss: 0.2953 - accuracy: 0.8796 - binary_crossentropy: 0.2953 - val_loss: 0.3301 - val_accuracy: 0.8591 - val_binary_crossentropy: 0.3301
# Epoch 15/20
# 49/49 - 0s - loss: 0.2945 - accuracy: 0.8788 - binary_crossentropy: 0.2945 - val_loss: 0.3294 - val_accuracy: 0.8583 - val_binary_crossentropy: 0.3294
# Epoch 16/20
# 49/49 - 0s - loss: 0.2909 - accuracy: 0.8822 - binary_crossentropy: 0.2909 - val_loss: 0.3288 - val_accuracy: 0.8584 - val_binary_crossentropy: 0.3288
# Epoch 17/20
# 49/49 - 0s - loss: 0.2885 - accuracy: 0.8826 - binary_crossentropy: 0.2885 - val_loss: 0.3293 - val_accuracy: 0.8592 - val_binary_crossentropy: 0.3293
# Epoch 18/20
# 49/49 - 0s - loss: 0.2861 - accuracy: 0.8835 - binary_crossentropy: 0.2861 - val_loss: 0.3299 - val_accuracy: 0.8581 - val_binary_crossentropy: 0.3299
# Epoch 19/20
# 49/49 - 0s - loss: 0.2846 - accuracy: 0.8836 - binary_crossentropy: 0.2846 - val_loss: 0.3307 - val_accuracy: 0.8578 - val_binary_crossentropy: 0.3307
# Epoch 20/20
# 49/49 - 0s - loss: 0.2823 - accuracy: 0.8846 - binary_crossentropy: 0.2823 - val_loss: 0.3311 - val_accuracy: 0.8586 - val_binary_crossentropy: 0.3311

# %% [markdown]
# ## 큰 모델 만들기

# %%
bigger_model = keras.models.Sequential([
    keras.layers.Dense(512, activation='relu', input_shape=(NUM_WORDS,)),
    keras.layers.Dense(512, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])

bigger_model.compile(optimizer='adam',
                     loss='binary_crossentropy',
                     metrics=['accuracy','binary_crossentropy'])

bigger_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_6 (Dense)              (None, 512)               512512
# _________________________________________________________________
# dense_7 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 775,681
# Trainable params: 775,681
# Non-trainable params: 0
# _________________________________________________________________

# %%
bigger_history = bigger_model.fit(train_data, train_labels,
                                  epochs=20,
                                  batch_size=512,
                                  validation_data=(test_data, test_labels),
                                  verbose=2)
# Out:
# Epoch 1/20
# 49/49 - 3s - loss: 0.4010 - accuracy: 0.8207 - binary_crossentropy: 0.4010 - val_loss: 0.3315 - val_accuracy: 0.8582 - val_binary_crossentropy: 0.3315
# Epoch 2/20
# 49/49 - 1s - loss: 0.2872 - accuracy: 0.8818 - binary_crossentropy: 0.2872 - val_loss: 0.3228 - val_accuracy: 0.8605 - val_binary_crossentropy: 0.3228
# Epoch 3/20
# 49/49 - 1s - loss: 0.2174 - accuracy: 0.9140 - binary_crossentropy: 0.2174 - val_loss: 0.3405 - val_accuracy: 0.8556 - val_binary_crossentropy: 0.3405
# Epoch 4/20
# 49/49 - 1s - loss: 0.1041 - accuracy: 0.9691 - binary_crossentropy: 0.1041 - val_loss: 0.4291 - val_accuracy: 0.8444 - val_binary_crossentropy: 0.4291
# Epoch 5/20
# 49/49 - 1s - loss: 0.0230 - accuracy: 0.9965 - binary_crossentropy: 0.0230 - val_loss: 0.5468 - val_accuracy: 0.8480 - val_binary_crossentropy: 0.5468
# Epoch 6/20
# 49/49 - 1s - loss: 0.0049 - accuracy: 0.9998 - binary_crossentropy: 0.0049 - val_loss: 0.6202 - val_accuracy: 0.8524 - val_binary_crossentropy: 0.6202
# Epoch 7/20
# 49/49 - 1s - loss: 0.0013 - accuracy: 1.0000 - binary_crossentropy: 0.0013 - val_loss: 0.6586 - val_accuracy: 0.8537 - val_binary_crossentropy: 0.6586
# Epoch 8/20
# 49/49 - 1s - loss: 7.2716e-04 - accuracy: 1.0000 - binary_crossentropy: 7.2716e-04 - val_loss: 0.6886 - val_accuracy: 0.8542 - val_binary_crossentropy: 0.6886
# Epoch 9/20
# 49/49 - 2s - loss: 5.1326e-04 - accuracy: 1.0000 - binary_crossentropy: 5.1326e-04 - val_loss: 0.7092 - val_accuracy: 0.8540 - val_binary_crossentropy: 0.7092
# Epoch 10/20
# 49/49 - 1s - loss: 3.9036e-04 - accuracy: 1.0000 - binary_crossentropy: 3.9036e-04 - val_loss: 0.7274 - val_accuracy: 0.8537 - val_binary_crossentropy: 0.7274
# Epoch 11/20
# 49/49 - 2s - loss: 3.0947e-04 - accuracy: 1.0000 - binary_crossentropy: 3.0947e-04 - val_loss: 0.7446 - val_accuracy: 0.8541 - val_binary_crossentropy: 0.7446
# Epoch 12/20
# 49/49 - 1s - loss: 2.5144e-04 - accuracy: 1.0000 - binary_crossentropy: 2.5144e-04 - val_loss: 0.7593 - val_accuracy: 0.8542 - val_binary_crossentropy: 0.7593
# Epoch 13/20
# 49/49 - 1s - loss: 2.0756e-04 - accuracy: 1.0000 - binary_crossentropy: 2.0756e-04 - val_loss: 0.7720 - val_accuracy: 0.8535 - val_binary_crossentropy: 0.7720
# Epoch 14/20
# 49/49 - 2s - loss: 1.7369e-04 - accuracy: 1.0000 - binary_crossentropy: 1.7369e-04 - val_loss: 0.7849 - val_accuracy: 0.8535 - val_binary_crossentropy: 0.7849
# Epoch 15/20
# 49/49 - 2s - loss: 1.4691e-04 - accuracy: 1.0000 - binary_crossentropy: 1.4691e-04 - val_loss: 0.7974 - val_accuracy: 0.8535 - val_binary_crossentropy: 0.7974
# Epoch 16/20
# 49/49 - 2s - loss: 1.2504e-04 - accuracy: 1.0000 - binary_crossentropy: 1.2504e-04 - val_loss: 0.8096 - val_accuracy: 0.8538 - val_binary_crossentropy: 0.8096
# Epoch 17/20
# 49/49 - 2s - loss: 1.0724e-04 - accuracy: 1.0000 - binary_crossentropy: 1.0724e-04 - val_loss: 0.8209 - val_accuracy: 0.8534 - val_binary_crossentropy: 0.8209
# Epoch 18/20
# 49/49 - 1s - loss: 9.2332e-05 - accuracy: 1.0000 - binary_crossentropy: 9.2332e-05 - val_loss: 0.8328 - val_accuracy: 0.8539 - val_binary_crossentropy: 0.8328
# Epoch 19/20
# 49/49 - 1s - loss: 7.9802e-05 - accuracy: 1.0000 - binary_crossentropy: 7.9802e-05 - val_loss: 0.8452 - val_accuracy: 0.8540 - val_binary_crossentropy: 0.8452
# Epoch 20/20
# 49/49 - 1s - loss: 6.9356e-05 - accuracy: 1.0000 - binary_crossentropy: 6.9356e-05 - val_loss: 0.8559 - val_accuracy: 0.8540 - val_binary_crossentropy: 0.8559

# %% [markdown]
# ## 훈련 손실과 검증 손실 그래프 그리기

# %%
def plot_history(histories, key='binary_crossentropy'):
  plt.figure(figsize=(16,10))

  for name, history in histories:
    val = plt.plot(history.epoch, history.history['val_'+key],
                   '--', label=name.title()+' Val')
    plt.plot(history.epoch, history.history[key], color=val[0].get_color(),
             label=name.title()+' Train')

  plt.xlabel('Epochs')
  plt.ylabel(key.replace('_',' ').title())
  plt.legend()

  plt.xlim([0,max(history.epoch)])


plot_history([('baseline', baseline_history),
              ('smaller', smaller_history),
              ('bigger', bigger_history)])

# %% [markdown]
# 큰 네트워크는 거의 바로 첫 번째 에포크 이후에 과대적합이 시작되고 훨씬 더 심각하게 과대적합됩니다.
#
# 네트워크의 용량이 많을수록 훈련 세트를 더 빠르게 모델링할 수 있습니다(훈련 손실이 낮아집니다).
#
# 하지만 더 쉽게 과대적합됩니다(훈련 손실과 검증 손실 사이에 큰 차이가 발생합니다).

# %% [markdown]
# ## 과대적합을 방지하기 위한 전략

# %% [markdown]
# 과대적합을 완화시키는 일반적인 방법은 가중치가 작은 값을 가지도록 네트워크의 복잡도에 제약을 가하는 것입니다. 이는 가중치 값의 분포를 좀 더 균일하게 만들어 줍니다. 이를 "가중치 규제"(weight regularization)라고 부릅니다. 네트워크의 손실 함수에 큰 가중치에 해당하는 비용을 추가합니다. 이 비용은 두 가지 형태가 있습니다:
#
# L1 규제는 가중치의 절댓값에 비례하는 비용이 추가됩니다(즉, 가중치의 "L1 노름(norm)"을 추가합니다).
#
# L2 규제는 가중치의 제곱에 비례하는 비용이 추가됩니다(즉, 가중치의 "L2 노름"의 제곱을 추가합니다). 신경망에서는 L2 규제를 가중치 감쇠(weight decay)라고도 부릅니다. 이름이 다르지만 혼돈하지 마세요. 가중치 감쇠는 수학적으로 L2 규제와 동일합니다.
#
# L1 규제는 일부 가중치 파라미터를 0으로 만듭니다. L2 규제는 가중치 파라미터를 제한하지만 완전히 0으로 만들지는 않습니다. 이것이 L2 규제를 더 많이 사용하는 이유 중 하나입니다.

# %%
l2_model = keras.models.Sequential([
    keras.layers.Dense(16, kernel_regularizer=keras.regularizers.l2(0.001),
                       activation='relu', input_shape=(NUM_WORDS,)),
    keras.layers.Dense(16, kernel_regularizer=keras.regularizers.l2(0.001),
                       activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])

l2_model.compile(optimizer='adam',
                 loss='binary_crossentropy',
                 metrics=['accuracy', 'binary_crossentropy'])

l2_model_history = l2_model.fit(train_data, train_labels,
                                epochs=20,
                                batch_size=512,
                                validation_data=(test_data, test_labels),
                                verbose=2)
# Out:
# Epoch 1/20
# 49/49 - 1s - loss: 0.6558 - accuracy: 0.6650 - binary_crossentropy: 0.6125 - val_loss: 0.5028 - val_accuracy: 0.8026 - val_binary_crossentropy: 0.4626
# Epoch 2/20
# 49/49 - 0s - loss: 0.4188 - accuracy: 0.8425 - binary_crossentropy: 0.3797 - val_loss: 0.3836 - val_accuracy: 0.8560 - val_binary_crossentropy: 0.3454
# Epoch 3/20
# 49/49 - 0s - loss: 0.3600 - accuracy: 0.8662 - binary_crossentropy: 0.3227 - val_loss: 0.3680 - val_accuracy: 0.8612 - val_binary_crossentropy: 0.3315
# Epoch 4/20
# 49/49 - 0s - loss: 0.3446 - accuracy: 0.8736 - binary_crossentropy: 0.3089 - val_loss: 0.3632 - val_accuracy: 0.8605 - val_binary_crossentropy: 0.3282
# Epoch 5/20
# 49/49 - 0s - loss: 0.3386 - accuracy: 0.8750 - binary_crossentropy: 0.3042 - val_loss: 0.3632 - val_accuracy: 0.8606 - val_binary_crossentropy: 0.3293
# Epoch 6/20
# 49/49 - 0s - loss: 0.3345 - accuracy: 0.8757 - binary_crossentropy: 0.3011 - val_loss: 0.3633 - val_accuracy: 0.8583 - val_binary_crossentropy: 0.3303
# Epoch 7/20
# 49/49 - 0s - loss: 0.3302 - accuracy: 0.8765 - binary_crossentropy: 0.2975 - val_loss: 0.3602 - val_accuracy: 0.8599 - val_binary_crossentropy: 0.3280
# Epoch 8/20
# 49/49 - 0s - loss: 0.3264 - accuracy: 0.8793 - binary_crossentropy: 0.2942 - val_loss: 0.3581 - val_accuracy: 0.8604 - val_binary_crossentropy: 0.3262
# Epoch 9/20
# 49/49 - 0s - loss: 0.3204 - accuracy: 0.8826 - binary_crossentropy: 0.2886 - val_loss: 0.3588 - val_accuracy: 0.8604 - val_binary_crossentropy: 0.3272
# Epoch 10/20
# 49/49 - 0s - loss: 0.3173 - accuracy: 0.8835 - binary_crossentropy: 0.2856 - val_loss: 0.3574 - val_accuracy: 0.8606 - val_binary_crossentropy: 0.3258
# Epoch 11/20
# 49/49 - 0s - loss: 0.3118 - accuracy: 0.8856 - binary_crossentropy: 0.2801 - val_loss: 0.3584 - val_accuracy: 0.8607 - val_binary_crossentropy: 0.3266
# Epoch 12/20
# 49/49 - 0s - loss: 0.3105 - accuracy: 0.8844 - binary_crossentropy: 0.2786 - val_loss: 0.3597 - val_accuracy: 0.8586 - val_binary_crossentropy: 0.3278
# Epoch 13/20
# 49/49 - 0s - loss: 0.3065 - accuracy: 0.8880 - binary_crossentropy: 0.2745 - val_loss: 0.3624 - val_accuracy: 0.8596 - val_binary_crossentropy: 0.3302
# Epoch 14/20
# 49/49 - 0s - loss: 0.3020 - accuracy: 0.8890 - binary_crossentropy: 0.2696 - val_loss: 0.3599 - val_accuracy: 0.8607 - val_binary_crossentropy: 0.3274
# Epoch 15/20
# 49/49 - 0s - loss: 0.2969 - accuracy: 0.8921 - binary_crossentropy: 0.2642 - val_loss: 0.3652 - val_accuracy: 0.8580 - val_binary_crossentropy: 0.3324
# Epoch 16/20
# 49/49 - 0s - loss: 0.2944 - accuracy: 0.8920 - binary_crossentropy: 0.2613 - val_loss: 0.3656 - val_accuracy: 0.8580 - val_binary_crossentropy: 0.3324
# Epoch 17/20
# 49/49 - 0s - loss: 0.2871 - accuracy: 0.8972 - binary_crossentropy: 0.2537 - val_loss: 0.3713 - val_accuracy: 0.8562 - val_binary_crossentropy: 0.3377
# Epoch 18/20
# 49/49 - 0s - loss: 0.2849 - accuracy: 0.8973 - binary_crossentropy: 0.2511 - val_loss: 0.3722 - val_accuracy: 0.8565 - val_binary_crossentropy: 0.3382
# Epoch 19/20
# 49/49 - 0s - loss: 0.2809 - accuracy: 0.8987 - binary_crossentropy: 0.2467 - val_loss: 0.3738 - val_accuracy: 0.8560 - val_binary_crossentropy: 0.3394
# Epoch 20/20
# 49/49 - 0s - loss: 0.2771 - accuracy: 0.9005 - binary_crossentropy: 0.2424 - val_loss: 0.3778 - val_accuracy: 0.8542 - val_binary_crossentropy: 0.3429

# %%
plot_history([('baseline', baseline_history),
              ('l2', l2_model_history)])

# %% [markdown]
# 드롭아웃 추가하기

# %% [markdown]
# 드롭아웃을 층에 적용하면 훈련하는 동안 층의 출력 특성을 랜덤하게 끕니다(즉, 0으로 만듭니다). 훈련하는 동안 어떤 입력 샘플에 대해 [0.2, 0.5, 1.3, 0.8, 1.1] 벡터를 출력하는 층이 있다고 가정해 보죠. 드롭아웃을 적용하면 이 벡터에서 몇 개의 원소가 랜덤하게 0이 됩니다. 예를 들면, [0, 0.5, 1.3, 0, 1.1]가 됩니다. "드롭아웃 비율"은 0이 되는 특성의 비율입니다. 보통 0.2에서 0.5 사이를 사용합니다. 테스트 단계에서는 어떤 유닛도 드롭아웃하지 않습니다. 훈련 단계보다 더 많은 유닛이 활성화되기 때문에 균형을 맞추기 위해 층의 출력 값을 드롭아웃 비율만큼 줄입니다.
#
# tf.keras에서는 Dropout 층을 이용해 네트워크에 드롭아웃을 추가할 수 있습니다. 이 층은 바로 이전 층의 출력에 드롭아웃을 적용합니다.

# %%
dpt_model = keras.models.Sequential([
    keras.layers.Dense(16, activation='relu', input_shape=(NUM_WORDS,)),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(16, activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(1, activation='sigmoid')
])

dpt_model.compile(optimizer='adam',
                  loss='binary_crossentropy',
                  metrics=['accuracy','binary_crossentropy'])

dpt_model_history = dpt_model.fit(train_data, train_labels,
                                  epochs=20,
                                  batch_size=512,
                                  validation_data=(test_data, test_labels),
                                  verbose=2)
# Out:
# Epoch 1/20
# 49/49 - 1s - loss: 0.6848 - accuracy: 0.5627 - binary_crossentropy: 0.6848 - val_loss: 0.6379 - val_accuracy: 0.7134 - val_binary_crossentropy: 0.6379
# Epoch 2/20
# 49/49 - 0s - loss: 0.6012 - accuracy: 0.6799 - binary_crossentropy: 0.6012 - val_loss: 0.4981 - val_accuracy: 0.8200 - val_binary_crossentropy: 0.4981
# Epoch 3/20
# 49/49 - 0s - loss: 0.5109 - accuracy: 0.7670 - binary_crossentropy: 0.5109 - val_loss: 0.4131 - val_accuracy: 0.8430 - val_binary_crossentropy: 0.4131
# Epoch 4/20
# 49/49 - 0s - loss: 0.4486 - accuracy: 0.8103 - binary_crossentropy: 0.4486 - val_loss: 0.3700 - val_accuracy: 0.8524 - val_binary_crossentropy: 0.3700
# Epoch 5/20
# 49/49 - 0s - loss: 0.4152 - accuracy: 0.8345 - binary_crossentropy: 0.4152 - val_loss: 0.3452 - val_accuracy: 0.8560 - val_binary_crossentropy: 0.3452
# Epoch 6/20
# 49/49 - 0s - loss: 0.3848 - accuracy: 0.8478 - binary_crossentropy: 0.3848 - val_loss: 0.3317 - val_accuracy: 0.8594 - val_binary_crossentropy: 0.3317
# Epoch 7/20
# 49/49 - 0s - loss: 0.3710 - accuracy: 0.8556 - binary_crossentropy: 0.3710 - val_loss: 0.3274 - val_accuracy: 0.8600 - val_binary_crossentropy: 0.3274
# Epoch 8/20
# 49/49 - 0s - loss: 0.3578 - accuracy: 0.8594 - binary_crossentropy: 0.3578 - val_loss: 0.3265 - val_accuracy: 0.8591 - val_binary_crossentropy: 0.3265
# Epoch 9/20
# 49/49 - 0s - loss: 0.3508 - accuracy: 0.8642 - binary_crossentropy: 0.3508 - val_loss: 0.3259 - val_accuracy: 0.8601 - val_binary_crossentropy: 0.3259
# Epoch 10/20
# 49/49 - 0s - loss: 0.3426 - accuracy: 0.8704 - binary_crossentropy: 0.3426 - val_loss: 0.3257 - val_accuracy: 0.8586 - val_binary_crossentropy: 0.3257
# Epoch 11/20
# 49/49 - 0s - loss: 0.3380 - accuracy: 0.8704 - binary_crossentropy: 0.3380 - val_loss: 0.3256 - val_accuracy: 0.8581 - val_binary_crossentropy: 0.3256
# Epoch 12/20
# 49/49 - 0s - loss: 0.3310 - accuracy: 0.8730 - binary_crossentropy: 0.3310 - val_loss: 0.3255 - val_accuracy: 0.8592 - val_binary_crossentropy: 0.3255
# Epoch 13/20
# 49/49 - 0s - loss: 0.3256 - accuracy: 0.8750 - binary_crossentropy: 0.3256 - val_loss: 0.3260 - val_accuracy: 0.8582 - val_binary_crossentropy: 0.3260
# Epoch 14/20
# 49/49 - 0s - loss: 0.3224 - accuracy: 0.8803 - binary_crossentropy: 0.3224 - val_loss: 0.3263 - val_accuracy: 0.8591 - val_binary_crossentropy: 0.3263
# Epoch 15/20
# 49/49 - 0s - loss: 0.3221 - accuracy: 0.8802 - binary_crossentropy: 0.3221 - val_loss: 0.3262 - val_accuracy: 0.8606 - val_binary_crossentropy: 0.3262
# Epoch 16/20
# 49/49 - 0s - loss: 0.3163 - accuracy: 0.8820 - binary_crossentropy: 0.3163 - val_loss: 0.3289 - val_accuracy: 0.8573 - val_binary_crossentropy: 0.3289
# Epoch 17/20
# 49/49 - 0s - loss: 0.3111 - accuracy: 0.8860 - binary_crossentropy: 0.3111 - val_loss: 0.3327 - val_accuracy: 0.8567 - val_binary_crossentropy: 0.3327
# Epoch 18/20
# 49/49 - 0s - loss: 0.3098 - accuracy: 0.8872 - binary_crossentropy: 0.3098 - val_loss: 0.3334 - val_accuracy: 0.8573 - val_binary_crossentropy: 0.3334
# Epoch 19/20
# 49/49 - 0s - loss: 0.3055 - accuracy: 0.8890 - binary_crossentropy: 0.3055 - val_loss: 0.3336 - val_accuracy: 0.8565 - val_binary_crossentropy: 0.3336
# Epoch 20/20
# 49/49 - 0s - loss: 0.3031 - accuracy: 0.8879 - binary_crossentropy: 0.3031 - val_loss: 0.3367 - val_accuracy: 0.8573 - val_binary_crossentropy: 0.3367

# %%
plot_history([('baseline', baseline_history),
              ('dropout', dpt_model_history)])

# %% [markdown]
# 정리하면 신경망에서 과대적합을 방지하기 위해 가장 널리 사용하는 방법은 다음과 같습니다:
#
# 더 많은 훈련 데이터를 모읍니다.
#
# 네트워크의 용량을 줄입니다.
#
# 가중치 규제를 추가합니다.
#
# 드롭아웃을 추가합니다.
