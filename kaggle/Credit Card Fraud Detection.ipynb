# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

# %% [markdown]
# 사기인지 아닌지 판별하는 것 class가 !

# %%
dataset = pd.DataFrame(pd.read_csv('csv_files/creditcard.csv'))

# %%
dataset.tail(10)
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284797  172782.0  -0.241923   0.712247  0.399806 -0.463406  0.244531
# 284798  172782.0   0.219529   0.881246 -0.635891  0.960928 -0.152971
# 284799  172783.0  -1.775135  -0.004235  1.189786  0.331096  1.196063
# 284800  172784.0   2.039560  -0.175233 -1.196825  0.234580 -0.008713
# 284801  172785.0   0.120316   0.931005 -0.546012 -0.745097  1.130314
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284797 -1.343668  0.929369 -0.206210  0.106234  ... -0.228876 -0.514376
# 284798 -1.014307  0.427126  0.121340 -0.285670  ...  0.099936  0.337120
# 284799  5.519980 -1.518185  2.080825  1.159498  ...  0.103302  0.654850
# 284800 -0.726571  0.017050 -0.118228  0.435402  ... -0.268048 -0.717211
# 284801 -0.235973  0.812722  0.115093 -0.204064  ... -0.314205 -0.808520
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# 284797  0.279598  0.371441 -0.559238  0.113144  0.131507  0.081265    5.49
# 284798  0.251791  0.057688 -1.508368  0.144023  0.181205  0.215243   24.05
# 284799 -0.348929  0.745323  0.704545 -0.127579  0.454379  0.130308   79.99
# 284800  0.297930 -0.359769 -0.315610  0.201114 -0.080826 -0.075071    2.68
# 284801  0.050343  0.102800 -0.435870  0.124079  0.217940  0.068803    2.69
# 284802  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731    0.77
# 284803  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527   24.79
# 284804 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561   67.88
# 284805 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533   10.00
# 284806  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649  217.00
#
#         Class
# 284797      0
# 284798      0
# 284799      0
# 284800      0
# 284801      0
# 284802      0
# 284803      0
# 284804      0
# 284805      0
# 284806      0
#
# [10 rows x 31 columns]

# %%
dataset[dataset.Time.isnull() == True ]
# Out:
# Empty DataFrame
# Columns: [Time, V1, V2, V3, V4, V5, V6, V7, V8, V9, V10, V11, V12, V13, V14, V15, V16, V17, V18, V19, V20, V21, V22, V23, V24, V25, V26, V27, V28, Amount, Class]
# Index: []
#
# [0 rows x 31 columns]

# %%
dataset[dataset.Time.isna() == True ]
# Out:
# Empty DataFrame
# Columns: [Time, V1, V2, V3, V4, V5, V6, V7, V8, V9, V10, V11, V12, V13, V14, V15, V16, V17, V18, V19, V20, V21, V22, V23, V24, V25, V26, V27, V28, Amount, Class]
# Index: []
#
# [0 rows x 31 columns]

# %%
dataset.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.919560e-15  5.688174e-16 -8.769071e-15  2.782312e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552563e-15  2.010663e-15 -1.694249e-15 -1.927028e-16 -3.137024e-15
# std    1.380247e+00  1.332271e+00  1.237094e+00  1.194353e+00  1.098632e+00
# min   -1.137433e+02 -2.616051e+01 -4.355724e+01 -7.321672e+01 -1.343407e+01
# 25%   -6.915971e-01 -7.682956e-01 -5.540759e-01 -2.086297e-01 -6.430976e-01
# 50%   -5.433583e-02 -2.741871e-01  4.010308e-02  2.235804e-02 -5.142873e-02
# 75%    6.119264e-01  3.985649e-01  5.704361e-01  3.273459e-01  5.971390e-01
# max    3.480167e+01  7.330163e+01  1.205895e+02  2.000721e+01  1.559499e+01
#
#        ...           V21           V22           V23           V24  \
# count  ...  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   ...  1.537294e-16  7.959909e-16  5.367590e-16  4.458112e-15
# std    ...  7.345240e-01  7.257016e-01  6.244603e-01  6.056471e-01
# min    ... -3.483038e+01 -1.093314e+01 -4.480774e+01 -2.836627e+00
# 25%    ... -2.283949e-01 -5.423504e-01 -1.618463e-01 -3.545861e-01
# 50%    ... -2.945017e-02  6.781943e-03 -1.119293e-02  4.097606e-02
# 75%    ...  1.863772e-01  5.285536e-01  1.476421e-01  4.395266e-01
# max    ...  2.720284e+01  1.050309e+01  2.252841e+01  4.584549e+00
#
#                 V25           V26           V27           V28         Amount  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  284807.000000
# mean   1.453003e-15  1.699104e-15 -3.660161e-16 -1.206049e-16      88.349619
# std    5.212781e-01  4.822270e-01  4.036325e-01  3.300833e-01     250.120109
# min   -1.029540e+01 -2.604551e+00 -2.256568e+01 -1.543008e+01       0.000000
# 25%   -3.171451e-01 -3.269839e-01 -7.083953e-02 -5.295979e-02       5.600000
# 50%    1.659350e-02 -5.213911e-02  1.342146e-03  1.124383e-02      22.000000
# 75%    3.507156e-01  2.409522e-01  9.104512e-02  7.827995e-02      77.165000
# max    7.519589e+00  3.517346e+00  3.161220e+01  3.384781e+01   25691.160000
#
#                Class
# count  284807.000000
# mean        0.001727
# std         0.041527
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
#
# [8 rows x 31 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
#  20  V20     284807 non-null  float64
#  21  V21     284807 non-null  float64
#  22  V22     284807 non-null  float64
#  23  V23     284807 non-null  float64
#  24  V24     284807 non-null  float64
#  25  V25     284807 non-null  float64
#  26  V26     284807 non-null  float64
#  27  V27     284807 non-null  float64
#  28  V28     284807 non-null  float64
#  29  Amount  284807 non-null  float64
#  30  Class   284807 non-null  int64
# dtypes: float64(30), int64(1)
# memory usage: 67.4 MB

# %%
dataset.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
y = dataset['Class']
y
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 284802    0
# 284803    0
# 284804    0
# 284805    0
# 284806    0
# Name: Class, Length: 284807, dtype: int64

# %%
dataset.drop(columns='Class', inplace=True)

# %%
dataset.shape
# Out:
# (284807, 30)

# %% [markdown]
# Splitting dataset into Train and Test set
#
# Split into 50% Training(Samples,Labels) , 30% Test(Samples,Labels) and 20% Validation Data(Samples,Labels).

# %%
# 142,400 record for trainning set
# 85,440 records for Testing set
# 56,960 records for validation
X_train = dataset[:142400]
X_test = dataset[142400:227840]
X_val = dataset[227840:]

# %%
X_train.shape
# Out:
# (142400, 30)

# %%
Y_train = y[:142400]
Y_test = y[142400:227840]
Y_val = y[227840:]

# %%
Y_train.shape
# Out:
# (142400,)

# %%
#Normalization
from sklearn.preprocessing import StandardScaler
X_train['Amount'] = StandardScaler().fit_transform(X_train['Amount'].values.reshape (-1,1))
X_test['Amount'] = StandardScaler().fit_transform(X_test['Amount'].values.reshape (-1,1))
X_val['Amount'] = StandardScaler().fit_transform(X_val['Amount'].values.reshape (-1,1))
# Out:
# C:\Users\chaeh\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\chaeh\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\chaeh\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers
from tensorflow.keras.regularizers import l2

# %%
network = Sequential()

# %%
network.add(layers.Dense(10, activation='relu', kernel_regularizer=l2(0.001), input_shape=(X_train.shape[1],)))
network.add(layers.Dense(8, activation='relu', kernel_regularizer=l2(0.001)))
network.add(layers.Dense(1, activation='sigmoid'))
#regularizers.l2(0.001) : 가중치 행렬의 모든 원소를 제곱하고 0.001을 곱하여 네트워크의 전체 손실에 더해진다는 의미
#이 규제(패널티)는 훈련할 때만 추가됨

# %%
network.compile(optimizer='adam', loss='binary_crossentropy', metrics='accuracy')
#모델을 학습시키기 이전에, compile 메소드를 통해서 학습 방식에 대한 환경설정을 해야 합니다. 
#optimizer는 nn을 구성하는 알고릴즘을 최적화 시켜주는 도구
#loss func는 예측값과 실제값사이를 알려주는것
#metrics는 화면상으로 출력되는 output=> 정확성을 알기위해 잘 된다 안된다를 구별

# %%
network_history = network.fit(X_train, Y_train, epochs=50, batch_size=500, validation_data=(X_val, Y_val))
# Out:
# Epoch 1/50
# 285/285 [==============================] - 3s 6ms/step - loss: 0.6876 - accuracy: 0.8482 - val_loss: 0.5725 - val_accuracy: 0.9987
# Epoch 2/50
# 285/285 [==============================] - 1s 3ms/step - loss: 0.5437 - accuracy: 0.9980 - val_loss: 0.4655 - val_accuracy: 0.9987
# Epoch 3/50
# 285/285 [==============================] - 1s 4ms/step - loss: 0.4438 - accuracy: 0.9982 - val_loss: 0.3831 - val_accuracy: 0.9987
# Epoch 4/50
# 285/285 [==============================] - 1s 4ms/step - loss: 0.3664 - accuracy: 0.9979 - val_loss: 0.3179 - val_accuracy: 0.9987
# Epoch 5/50
# 285/285 [==============================] - 1s 4ms/step - loss: 0.3046 - accuracy: 0.9981 - val_loss: 0.2658 - val_accuracy: 0.9987
# Epoch 6/50
# 285/285 [==============================] - 1s 4ms/step - loss: 0.2556 - accuracy: 0.9980 - val_loss: 0.2239 - val_accuracy: 0.9987
# Epoch 7/50
# 285/285 [==============================] - 1s 4ms/step - loss: 0.2158 - accuracy: 0.9981 - val_loss: 0.1899 - val_accuracy: 0.9987
# Epoch 8/50
# 285/285 [==============================] - 1s 4ms/step - loss: 0.1832 - accuracy: 0.9983 - val_loss: 0.1621 - val_accuracy: 0.9987
# Epoch 9/50
# 285/285 [==============================] - 1s 4ms/step - loss: 0.1573 - accuracy: 0.9980 - val_loss: 0.1392 - val_accuracy: 0.9987
# Epoch 10/50
# 285/285 [==============================] - 1s 4ms/step - loss: 0.1352 - accuracy: 0.9982 - val_loss: 0.1202 - val_accuracy: 0.9987
# Epoch 11/50
# 285/285 [==============================] - 1s 3ms/step - loss: 0.1173 - accuracy: 0.9981 - val_loss: 0.1043 - val_accuracy: 0.9987
# Epoch 12/50
# 285/285 [==============================] - 1s 3ms/step - loss: 0.0903 - accuracy: 0.9981 - val_loss: 0.0141 - val_accuracy: 0.9987
# Epoch 13/50
# 285/285 [==============================] - 1s 4ms/step - loss: 0.0174 - accuracy: 0.9980 - val_loss: 0.0131 - val_accuracy: 0.9987
# Epoch 14/50
# 285/285 [==============================] - 1s 4ms/step - loss: 0.0157 - accuracy: 0.9982 - val_loss: 0.0126 - val_accuracy: 0.9987
# Epoch 15/50
# 285/285 [==============================] - 1s 4ms/step - loss: 0.0146 - accuracy: 0.9983 - val_loss: 0.0121 - val_accuracy: 0.9987
# Epoch 16/50
# 285/285 [==============================] - 1s 4ms/step - loss: 0.0152 - accuracy: 0.9981 - val_loss: 0.0116 - val_accuracy: 0.9987
# Epoch 17/50
# 285/285 [==============================] - 1s 4ms/step - loss: 0.0151 - accuracy: 0.9981 - val_loss: 0.0113 - val_accuracy: 0.9987
# Epoch 18/50
# 285/285 [==============================] - 1s 4ms/step - loss: 0.0141 - accuracy: 0.9982 - val_loss: 0.0111 - val_accuracy: 0.9987
# Epoch 19/50
# 285/285 [==============================] - 1s 4ms/step - loss: 0.0153 - accuracy: 0.9980 - val_loss: 0.0109 - val_accuracy: 0.9987
# Epoch 20/50
# 285/285 [==============================] - 1s 4ms/step - loss: 0.0139 - accuracy: 0.9982 - val_loss: 0.0107 - val_accuracy: 0.9987
# Epoch 21/50
# 285/285 [==============================] - 1s 4ms/step - loss: 0.0135 - accuracy: 0.9982 - val_loss: 0.0106 - val_accuracy: 0.9987
# Epoch 22/50
# 285/285 [==============================] - 1s 4ms/step - loss: 0.0153 - accuracy: 0.9979 - val_loss: 0.0105 - val_accuracy: 0.9987
# Epoch 23/50
# 285/285 [==============================] - 1s 3ms/step - loss: 0.0144 - accuracy: 0.9980 - val_loss: 0.0104 - val_accuracy: 0.9987
# Epoch 24/50
# 285/285 [==============================] - 1s 3ms/step - loss: 0.0143 - accuracy: 0.9981 - val_loss: 0.0103 - val_accuracy: 0.9987
# Epoch 25/50
# 285/285 [==============================] - 1s 3ms/step - loss: 0.0142 - accuracy: 0.9981 - val_loss: 0.0103 - val_accuracy: 0.9987
# Epoch 26/50
# 285/285 [==============================] - 1s 4ms/step - loss: 0.0137 - accuracy: 0.9981 - val_loss: 0.0103 - val_accuracy: 0.9987
# Epoch 27/50
# 285/285 [==============================] - 1s 4ms/step - loss: 0.0147 - accuracy: 0.9980 - val_loss: 0.0102 - val_accuracy: 0.9987
# Epoch 28/50
# 285/285 [==============================] - 1s 4ms/step - loss: 0.0125 - accuracy: 0.9983 - val_loss: 0.0104 - val_accuracy: 0.9987
# Epoch 29/50
# 285/285 [==============================] - 1s 4ms/step - loss: 0.0137 - accuracy: 0.9981 - val_loss: 0.0103 - val_accuracy: 0.9987
# Epoch 30/50
# 285/285 [==============================] - 1s 4ms/step - loss: 0.0143 - accuracy: 0.9980 - val_loss: 0.0102 - val_accuracy: 0.9987
# Epoch 31/50
# 285/285 [==============================] - 1s 4ms/step - loss: 0.0148 - accuracy: 0.9980 - val_loss: 0.0102 - val_accuracy: 0.9987
# Epoch 32/50
# 285/285 [==============================] - 1s 4ms/step - loss: 0.0140 - accuracy: 0.9981 - val_loss: 0.0101 - val_accuracy: 0.9987
# Epoch 33/50
# 285/285 [==============================] - 1s 4ms/step - loss: 0.0137 - accuracy: 0.9981 - val_loss: 0.0102 - val_accuracy: 0.9987
# Epoch 34/50
# 285/285 [==============================] - 1s 4ms/step - loss: 0.0138 - accuracy: 0.9981 - val_loss: 0.0102 - val_accuracy: 0.9987
# Epoch 35/50
# 285/285 [==============================] - 1s 4ms/step - loss: 0.0140 - accuracy: 0.9981 - val_loss: 0.0102 - val_accuracy: 0.9987
# Epoch 36/50
# 285/285 [==============================] - 1s 4ms/step - loss: 0.0137 - accuracy: 0.9981 - val_loss: 0.0101 - val_accuracy: 0.9987
# Epoch 37/50
# 285/285 [==============================] - 1s 4ms/step - loss: 0.0147 - accuracy: 0.9980 - val_loss: 0.0102 - val_accuracy: 0.9987
# Epoch 38/50
# 285/285 [==============================] - 1s 4ms/step - loss: 0.0141 - accuracy: 0.9981 - val_loss: 0.0101 - val_accuracy: 0.9987
# Epoch 39/50
# 285/285 [==============================] - 1s 4ms/step - loss: 0.0149 - accuracy: 0.9979 - val_loss: 0.0102 - val_accuracy: 0.9987
# Epoch 40/50
# 285/285 [==============================] - 1s 5ms/step - loss: 0.0136 - accuracy: 0.9981 - val_loss: 0.0102 - val_accuracy: 0.9987
# Epoch 41/50
# 285/285 [==============================] - 1s 5ms/step - loss: 0.0139 - accuracy: 0.9981 - val_loss: 0.0101 - val_accuracy: 0.9987
# Epoch 42/50
# 285/285 [==============================] - 1s 4ms/step - loss: 0.0137 - accuracy: 0.9981 - val_loss: 0.0101 - val_accuracy: 0.9987
# Epoch 43/50
# 285/285 [==============================] - 1s 3ms/step - loss: 0.0129 - accuracy: 0.9982 - val_loss: 0.0102 - val_accuracy: 0.9987
# Epoch 44/50
# 285/285 [==============================] - 1s 4ms/step - loss: 0.0140 - accuracy: 0.9981 - val_loss: 0.0101 - val_accuracy: 0.9987
# Epoch 45/50
# 285/285 [==============================] - 1s 4ms/step - loss: 0.0134 - accuracy: 0.9982 - val_loss: 0.0103 - val_accuracy: 0.9987
# Epoch 46/50
# 285/285 [==============================] - 1s 4ms/step - loss: 0.0142 - accuracy: 0.9980 - val_loss: 0.0102 - val_accuracy: 0.9987
# Epoch 47/50
# 285/285 [==============================] - 1s 3ms/step - loss: 0.0135 - accuracy: 0.9981 - val_loss: 0.0101 - val_accuracy: 0.9987
# Epoch 48/50
# 285/285 [==============================] - 1s 4ms/step - loss: 0.0138 - accuracy: 0.9981 - val_loss: 0.0101 - val_accuracy: 0.9987
# Epoch 49/50
# 285/285 [==============================] - 1s 4ms/step - loss: 0.0149 - accuracy: 0.9979 - val_loss: 0.0101 - val_accuracy: 0.9987
# Epoch 50/50
# 285/285 [==============================] - 1s 4ms/step - loss: 0.0147 - accuracy: 0.9980 - val_loss: 0.0102 - val_accuracy: 0.9987

# %%
train_loss = network_history.history['loss']

# %%
val_loss = network_history.history['val_loss']

# %%
epochs = range(1,51)

# %%
plt.plot(epochs, train_loss, 'r', label='Training Loss' )
plt.plot(epochs, val_loss, 'g', label='Validation Loss')
plt.title('Training and Validation loss Plot.')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
network.predict(X_test)
# Out:
# array([[0.00191632],
#        [0.00191632],
#        [0.00191632],
#        ...,
#        [0.00191632],
#        [0.00191632],
#        [0.00191632]], dtype=float32)

# %%
network.evaluate(X_test, Y_test) #loss와 accuracy
# Out:
# 2670/2670 [==============================] - 7s 3ms/step - loss: 0.0128 - accuracy: 0.9983
# [0.012754619121551514, 0.9982677698135376]
